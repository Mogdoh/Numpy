# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### 산점도
#     - 두 연속형 변수의 상관관계를 나타내는 그래프

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### 색상과 크기
# > plt.scatter(x,y, s= area, c= colors)
#
#     - s: size
#     - c: color

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30*np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x,y, s=area, c= colors)
plt.show()

# 4차원의 정보가 그래프로 표현되어 있다

# %% [markdown]
# ### 투명도와 컬러맵
#
# > plt.scatter(x,y, alpha = 0.5, cmap='Spectral')
#
#     - alpha: 투명도
#     - cmap: colormap

# %%
plt.scatter(x,y, s=area, c= colors, alpha = 0.5, cmap= 'Spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# # 히스토그램
#
#     - 표로 되어있는 도수 분포를 정보 그림으로 나타낸것

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]
          
plt.hist(weight)
plt.show()

# 기존의 바 그래프는 범주형을 x 축으로 지정하여 사용하지만 히스토그램은 수치형으로
# 이를 표현하기 때문에 서로 붙어 있는 모습을 확인 할 수 있다.

# %% [markdown]
# ### 구간 개수 지정
#
#     - bins 파라미터의 가로 축 구간의 개수를 지정한다

# %%
plt.hist(weight, bins= 20)
plt.show()

# %% [markdown]
# ### 누적 히스토 그램
#     - cumulative 파라미터를 True로 지정하면 누적으로 보여준다

# %%
plt.hist(weight, cumulative=True, label='cumulative=True')
plt.hist(weight, cumulative=False, label='cumulative=False')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 히스토 그램 종류

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
        80, 59, 67, 81, 69, 73, 69, 74, 70, 65]
weight2 = [52, 67, 84, 66, 58, 78, 71, 57, 76, 62, 51, 79,
        69, 64, 76, 57, 63, 53, 79, 64, 50, 61]

fig, ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].hist((weight, weight2), histtype='bar')
ax[0,0].set_title('histtype - bar')

ax[0,1].hist((weight, weight2), histtype='barstacked')
ax[0,1].set_title('histtype - barstacked')

ax[1,0].hist((weight, weight2), histtype='step')
ax[1,0].set_title('histtype - step')

ax[1,1].hist((weight, weight2), histtype='stepfilled')
ax[1,1].set_title('histtype - stepfilled')
# Out:
# Text(0.5, 1.0, 'histtype - stepfilled')

# %% [markdown]
# ### 에러바(오차막대)
#
# > 데이터의 편차를 표시하기 위한 그래프

# %%
x =[1,2,3,4]
y = [1,4,9,16]
yerr = [2.3,3.1,1.5,1.7]

plt.errorbar(x,y,yerr=yerr)
plt.show()

# %% [markdown]
# ### 비대칭 편차

# %%
yerr = [(2.3,3.1,1.7,2.5), (1.1,2.5,0.9,3.9)]

plt.errorbar(x,y,yerr=yerr)
plt.show()

#x,y 값 지표를 기준으로 편차가 비대칭으로 나눠진 것을 확인 할 수 있다

# %% [markdown]
# ### 파이차트
#
#     - 범주형 자료를 나타내주는 대표적인 함수

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]

plt.pie(ratio, labels = labels, autopct='%.1f%%')
plt.show()

# %%
# 각도와 방향을 조정

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False)
plt.show()

# %%
# 중심에서 벗어난 정도
# explode
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# 그림자 표현
# plt.pie(ratio, shadow =True)
explode = [0.05, 0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.show()

# %%
# 색깔
colors = ['silver','gold','whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors = colors)
plt.show()

# %%
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors = colors)
plt.show()

# %%
# 부채꼴 스타일 표현
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# ### 히트맵(heatmap)
#
#     - 다양한 값을 갖는 숫자 데이터를 열분포 형태와 같이 색상을 이용하여 시각화한 것

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)

plt.show()

# %% [markdown]
# ### 컬러바 나타내기
#
#     -matshow

# %%
plt.matshow(arr)
plt.colorbar()

plt.show()

# %% [markdown]
# ### 색상 범위 지정하기

# %%
plt.matshow(arr)
plt.colorbar(shrink = 0.8, aspect =10)
plt.clim(-1.0, 1.0)

plt.show()

# %% [markdown]
# ### 컬러맵 지정하기

# %%
cmap = plt.get_cmap('bwr')

plt.matshow(arr, cmap=cmap)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 박스 플롯 그리기
#
#     -박스 플롯은 수치 데이터를 표현하는 그래프이다. 일반적으로 박스플롯은 전체 데이터로부터 얻어진 아래의 다섯 가지 요약 수치를 사용해서 그려진다.

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
np.random.seed(0)
data_a = np.random.normal(0, 2.0, 1000)
data_b = np.random.normal(-3.0, 1.5, 500)
data_c = np.random.normal(1.2, 1.5, 1500)

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.boxplot([data_a, data_b, data_c])
ax.set_ylim(-10.0, 10.0)
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')

plt.show()

# %% [markdown]
# ### 두 종류의 그래프 그리기

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis='y', direction='in')

plt.show()

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis='y', direction='in')

# 4. 그래프 순서 지정
ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
